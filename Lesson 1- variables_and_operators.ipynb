# %% [markdown]
# # Variables

# %%
people = 10

# %%
print(people)
# Out:
# 10

# %%
last_name = "Cooper"

# %%
print(last_name)
# Out:
# Cooper

# %%
adds = 2 + 2
print(adds)
# Out:
# 4

# %%
people = 100

# %%
print(people)
# Out:
# 100

# %% [markdown]
# # Arithmetic Operators

# %%
add = 2 + 2
sub = 2 - 2
mult = 2 * 2
div = 2 / 2
fl_div = 2 // 2
power = 2 ** 8
mod = 4 % 2

print(mult)
print(power)
# Out:
# 4
# 256

# %% [markdown]
# # Comparison Operators

# %%
10 > 12
# Out:
# False

# %%
12 > 10
# Out:
# True

# %%
7 < 9
# Out:
# True

# %%
10 == 12
# Out:
# False

# %%
11 == 11
# Out:
# True

# %%
8 <= 9
# Out:
# True

# %%
9 >= 9
# Out:
# True

# %%
6 != 8
# Out:
# True

# %%
8 != 8
# Out:
# False

# %% [markdown]
# # Logical Operators

# %% [markdown]
# ### AND

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
10 > 12 and 2 * 2 ==  4
# Out:
# False

# %%
10 == 10 and 2 * 2 == 4
# Out:
# True

# %% [markdown]
# ### OR

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
10 > 12 or 2 * 2 ==  4
# Out:
# True

# %% [markdown]
# ### NOT

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
not 5
# Out:
# False
