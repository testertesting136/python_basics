# %% [markdown]
# # Dictionaries

# %%
student = ["Maya", 16, 92]
print(student[0])
print(student[1])
print(student[2])
# Out:
# Maya
# 16
# 92

# %%
student = {
    "name": "Maya",
    "age": 16,
    "grade": 92
}

# %%
student_name = student["name"]
student_grade = student["grade"]

# %%
student_grade + 5
# Out:
# 97

# %%
student["grade"] = 97

# %%
print(student["grade"])
# Out:
# 97

# %%
student["passed"] = True

# %%
print(student)
# Out:
# {'name': 'Maya', 'age': 16, 'grade': 97, 'passed': True}

# %%
print(student.get("email"))
# Out:
# None

# %%
print(student.get("age"))
# Out:
# 16

# %%
print(student.get("email", "No email provided"))
# Out:
# No email provided

# %%
student.pop("passed")
# Out:
# True

# %%
print(student)
# Out:
# {'name': 'Maya', 'age': 16, 'grade': 97}

# %%
if "grade" in student:
    print("The grade is availible")
else:
    print("The grade is not availible")
# Out:
# The grade is availible

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
print(student.values())
# Out:
# dict_values(['Maya', 16, 97])

# %%
print(student.items())
# Out:
# dict_items([('name', 'Maya'), ('age', 16), ('grade', 97)])

# %%
for key in student.keys():
    print(key)
# Out:
# name
# age
# grade

# %%
for key, value in student.items():
    print(key, value)
# Out:
# name Maya
# age 16
# grade 97

# %%
temp = [21, 45, 23, 23, 15, 90]

# %%
sample = {
    "sample_id": "A-01",
    "temperature": 22,
    "treatment": "control"
    
}
